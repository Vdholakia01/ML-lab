# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
#import matplotlib.pyplot as plt

# %%
studentname=['Mehul','Harshil','Pratham','Prit','Vrutik']
studmarks=[90,45,60,78,80]
Course=['IMSCIT','IMSCIT','IMSCIT','IMSCIT','IMSCIT']
grade=['O','C','B','B','O']
HSC=[80,65,87,31,87]
gender=['M','M','M','M','M']
graduation=['IMSCIT','IMSCIT','IMSCIT','IMSCIT','IMSCIT']
nameser=pd.Series(studentname)
markser=pd.Series(studmarks)
courser=pd.Series(Course)
gradeser=pd.Series(grade)
hscser=pd.Series(HSC)
genderser=pd.Series(gender)
graduationser=pd.Series(graduation)
df2=pd.DataFrame({'Name':nameser,'Course':courser,'Marks':markser,'HSC':hscser,'Grade':gradeser,'Gender':genderser})
df2
# Out:
#       Name  Course  Marks  HSC Grade Gender
# 0    Mehul  IMSCIT     90   80     O      M
# 1  Harshil  IMSCIT     45   65     C      M
# 2  Pratham  IMSCIT     60   87     B      M
# 3     Prit  IMSCIT     78   31     B      M
# 4   Vrutik  IMSCIT     80   87     O      M

# %%
import seaborn as ans
ans.lineplot(df2['HSC'],df2['Marks'],hue=df1['Course'],color="red")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='HSC', ylabel='Marks'>

# %%
#distanceplot using seaborn
ans.distplot(df2['HSC'],kde=False,bins=10)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='HSC'>

# %%
#boxplot using seaborn
ans.boxplot(df2['Marks'],color="green")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Marks'>

# %%
#Histogram plot using seaborn
ans.histplot(df2['HSC'],color="black")
# Out:
# <AxesSubplot:xlabel='HSC', ylabel='Count'>

# %%
#Scatter plot using seaborn
ans.scatterplot(df2['HSC'],df2['Marks'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='HSC', ylabel='Marks'>

# %%
ans.distplot(df2['HSC'],kde=True,bins=10)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='HSC', ylabel='Density'>

# %%
ans.violinplot(df2['HSC'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='HSC'>

# %%
ans.swarmplot(df2['HSC'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='HSC'>

# %%
ans.pointplot(df2['HSC'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='HSC'>

# %%
ans.kdeplot(df2['Marks'],df2['HSC'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Marks', ylabel='HSC'>
