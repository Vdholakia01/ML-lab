# %%
import pandas as pd

# %%
df=pd.read_csv('ml.csv')

# %%
df
# Out:
#     Courses  Enrollment No.     Name  M/F Date of Birth Permanent City  \
# 0       BCA    2.019016e+09    Mehul    M    10/12/2001      Dungrapur
# 1       MCA    2.019016e+09    Priti    F    11/03/2001      Ahmedabad
# 2      MCOM    2.019016e+09     Prit    M    17/04/2001      Ahmedabad
# 3      BCOM    2.019016e+09  Harshil    M    26/08/2001          Surat
# 4    BSC-IT    2.019016e+09     Isha    F    26/04/2001         Rajkot
# 5    MSC-IT    2.019016e+09    Hemal    M    15/07/2001        Vadodra
# 6     MTECH    2.019016e+09    Ishit    M    19/08/2001           Bhuj
# 7     BTECH    2.019016e+09    Kiran    F    20/03/2001         Mundra
# 8   I-MSCIT    2.019016e+09    Karan    M        24-Aug      Ahmedabad
# 9       LAW    2.019016e+09   Sakshi    F    29/09/2001         Mundra
# 10      NaN             NaN      NaN  NaN           NaN            NaN
# 11      NaN             NaN      NaN  NaN           NaN            NaN
# ...

# %%
df.head(5)
# Out:
#   Courses  Enrollment No.     Name M/F Date of Birth Permanent City  \
# 0     BCA    2.019016e+09    Mehul   M    10/12/2001      Dungrapur
# 1     MCA    2.019016e+09    Priti   F    11/03/2001      Ahmedabad
# 2    MCOM    2.019016e+09     Prit   M    17/04/2001      Ahmedabad
# 3    BCOM    2.019016e+09  Harshil   M    26/08/2001          Surat
# 4  BSC-IT    2.019016e+09     Isha   F    26/04/2001         Rajkot
#
#      Mobile No.           Email-id  SSC(%)  HSC(%)  Graduation  Degree  \
# 0  1.235490e+09    mehul@gmail.com    78.0    80.0        80.0     BCA
# 1  1.236546e+09    priti@gmail.com    85.0    90.0        70.0     MCA
# 2  3.165156e+09     prit@gmail.com    63.0    60.0        60.0    MCOM
# 3  3.131313e+09  harshil@gmail.com    84.0    40.0        50.0    BCOM
# 4  3.213131e+09     isha@gmail.com    90.0    55.0        55.0  BSC-IT
#
#   University  PG Avg(%)
# 0     Gujrat       80.0
# 1        GLS       85.0
# 2        GLS       60.0
# 3  Ahmedabad       70.0
# ...

# %%
df.Name.head(3)
# Out:
# 0    Mehul
# 1    Priti
# 2     Prit
# Name: Name, dtype: object

# %%
df.query('Graduation')
